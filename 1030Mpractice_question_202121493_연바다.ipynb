# %%
import pandas as pd

# %%
import pandas as pd
지역=pd.Series(['부천','인천','서울']) #데이터프레임을 만들었음에도 지역을 입력하지 않으면 저장만하고 출력x
지역
# Out:
# 0    부천
# 1    인천
# 2    서울
# dtype: object

# %%
import pandas as pd
df=pd.DataFrame({'지역':['부천','인천','서울'],  #이 코딩으로 인해 df라는 변수가 제일 최근에 저장된 이 값들로 바뀜(업데이트)
                 '평균기온':[20,10,15]})
df           #데이터프레임(정해진 단어x)
# Out:
#    지역  평균기온
# 0  부천    20
# 1  인천    10
# 2  서울    15

# %%
import pandas as pd
df=pd.DataFrame({'지역':['부천','인천','서울'],
                 '속성':['최고온도','최저온도','평균온도'],
                 '값':[20,10,15]})
df
# Out:
#    지역    속성   값
# 0  부천  최고온도  20
# 1  인천  최저온도  10
# 2  서울  평균온도  15

# %%
import pandas as pd #이게 없으면 NameError
#연습 1.

df=pd.DataFrame({'지역':['부천', '인천', '서울' ],
                 '풍속(m/s)':['5', '6.5', '4' ],
                 '온도(°C)':[20, 10, 15 ]})
df
# Out:
#    지역 풍속(m/s)  온도(°C)
# 0  부천       5      20
# 1  인천     6.5      10
# 2  서울       4      15

# %%
#연습 2.
import pandas as pd
df=pd.DataFrame({'지역':['부천','서울'],
                '풍속(m/s)':['1', '1.5'],
                 '온도(°C)':[15, 13],
                '습도(%)':[64, 62],
                 '기압(hPa)':[1022, 1022]})
df
# Out:
#    지역 풍속(m/s)  온도(°C)  습도(%)  기압(hPa)
# 0  부천       1      15     64     1022
# 1  서울     1.5      13     62     1022

# %%
#연습 3
import pandas as pd
df=pd.DataFrame({'지역':['부천','서울','대전','춘천'],
                '풍속(m/s)':['1', '1.5','2','3'],
                 '온도(°C)':[15, 13, 10, 8],
                '습도(%)':[64, 62, 63, 65],
                 '기압(hPa)':[1022, 1022, 1022, 1022] })
df
# Out:
#    지역 풍속(m/s)  온도(°C)  습도(%)  기압(hPa)
# 0  부천       1      15     64     1022
# 1  서울     1.5      13     62     1022
# 2  대전       2      10     63     1022
# 3  춘천       3       8     65     1022

# %%
#첫 줄 없어도 네임오류x
df = pd.read_csv('/content/sample_data/music.csv')
df
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
df = pd.read_excel('/content/sample_data/weather.xlsx')
df
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 3  2022-06-04  25.6  20.3  29.7
# 4  2022-06-05  22.7  20.2  27.0
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 17 2022-06-18  23.3  22.0  25.1
# 18 2022-06-19  23.4  22.3  25.1
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 22 2022-06-23  24.3  23.3  26.4
# 23 2022-06-24  22.6  20.6  24.9
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# ...

# %%
import pandas as pd
filename='/content/sample_data/music.csv'
df = pd.read_csv(filename) #따로 변수로 지정
df
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         13 non-null     object
#  1   singer        13 non-null     object
#  2   personnel     13 non-null     int64
#  3   sortation     13 non-null     object
#  4   release_date  13 non-null     object
#  5   agency        13 non-null     object
#  6   genre         13 non-null     object
#  7   type          13 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 960.0+ bytes

# %%
#상위 5개의 데이터만 출력

df.head()
# Out:
#      title singer  personnel sortation release_date     agency genre type
# 0      좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 2    강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 3     첫사랑니   f(x)          5        그룹   2013-07-29   SM엔터테인먼트    댄스   정규
# 4      위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글

# %%
#하위 5개의 데이터만 출력
df.tail()
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# 11      달라달라     있지          5        그룹   2019-02-12              JYP엔터테인먼트
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
#
#    genre type
# 8     댄스   EP
# 9     댄스   EP
# 10    댄스   EP
# 11    댄스   싱글
# 12    댄스   싱글

# %%
#상위 10개의 데이터 출력
df.head(10)
# Out:
#      title singer  personnel sortation release_date                 agency  \
# 0      좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2    강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3     첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4      위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5  Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6     피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7   시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8      빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9     에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
#
#   genre type
# 0   발라드   EP
# 1    댄스   싱글
# 2    힙합   정규
# 3    댄스   정규
# 4    댄스   싱글
# 5    댄스   EP
# 6   R&B   정규
# 7    댄스   EP
# ...

# %%
#요약 통계량 확인하기: 수치형 칼럼
df.describe()
# Out:
#        personnel
# count  13.000000
# mean    5.230769
# std     2.712743
# min     1.000000
# 25%     4.000000
# 50%     5.000000
# 75%     7.000000
# max    11.000000

# %%
#데이터 행/열 크기 확인
df.shape
# Out:
# (13, 8)

# %%
#인덱스 출력
df.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
#칼럼 출력
df.columns
# Out:
# Index(['title', 'singer', 'personnel', 'sortation', 'release_date', 'agency',
#        'genre', 'type'],
#       dtype='object')

# %%
#데이터 타입 확인
df.dtypes
# Out:
# title           object
# singer          object
# personnel        int64
# sortation       object
# release_date    object
# agency          object
# genre           object
# type            object
# dtype: object

# %%
#발매일 칼럼의 크기에 따라 오름차순 정렬
df.sort_values('release_date')
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
#인원수 칼럼의 값 크기에 따라 내림차순 정렬
#상위 5개의 데이터 (행) 만 출력
df.sort_values('personnel',ascending=False).head()
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
#
#    genre type
# 9     댄스   EP
# 5     댄스   EP
# 6    R&B   정규
# 12    댄스   싱글
# 7     댄스   EP

# %%
#인원수, 가수명 칼럼의 값에 따른 오름차순 정렬.
#상위 5개만 출력
df.sort_values(['personnel','singer']).head()
# Out:
#       title singer  personnel sortation release_date     agency genre type
# 2     강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 0       좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1   내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 4       위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글
# 10     뚜두뚜두   블랙핑크          4        그룹   2018-06-15   YG엔터테인먼트    댄스   EP

# %%
#기획사별 빈도수 구하기
cnt=df['agency'].value_counts()
pd.DataFrame(cnt)
# Out:
#                        agency
# YG엔터테인먼트                    3
# SM엔터테인먼트                    2
# 빅히트뮤직                       2
# 카카오엔터테인먼트                   1
# 바나나컬쳐                       1
# 울림엔터테인먼트                    1
# 쏘스뮤직                        1
# YMC엔터테인먼트, 스톤뮤직엔터테인먼트       1
# JYP엔터테인먼트                   1

# %%
#칼럼의 고윳값 출력하기
df['agency'].unique()
# Out:
# array(['카카오엔터테인먼트', 'YG엔터테인먼트', 'SM엔터테인먼트', '바나나컬쳐', '울림엔터테인먼트', '빅히트뮤직',
#        '쏘스뮤직', 'YMC엔터테인먼트, 스톤뮤직엔터테인먼트', 'JYP엔터테인먼트'], dtype=object)

# %%
#연습 4-1
import pandas as pd
filename2='/content/sample_data/weather.xlsx'#xlsx파일 읽을 때 read_excel
df2 = pd.read_excel(filename2)
df2
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 3  2022-06-04  25.6  20.3  29.7
# 4  2022-06-05  22.7  20.2  27.0
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 17 2022-06-18  23.3  22.0  25.1
# 18 2022-06-19  23.4  22.3  25.1
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 22 2022-06-23  24.3  23.3  26.4
# 23 2022-06-24  22.6  20.6  24.9
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# ...

# %%
#연습 4 -2 변수 속성파악
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      30 non-null     datetime64[ns]
#  1   평균기온    30 non-null     float64
#  2   최저기온    30 non-null     float64
#  3   최고기온    30 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 1.1 KB

# %%
#연습 4 -3 df2의 상위 5행 출력
df2.head()
# Out:
#           날짜  평균기온  최저기온  최고기온
# 0 2022-06-01  22.1  16.2  28.6
# 1 2022-06-02  21.5  17.1  26.9
# 2 2022-06-03  24.5  18.7  32.6
# 3 2022-06-04  25.6  20.3  29.7
# 4 2022-06-05  22.7  20.2  27.0

# %%
#연습 4 -4 df2 하위 5행 출력
df2.tail()
# Out:
#            날짜  평균기온  최저기온  최고기온
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# 28 2022-06-29  25.1  24.4  26.1
# 29 2022-06-30  22.3  21.2  24.5

# %%
#연습 4 -5 df2의 상위 8행 출력
df2.head(8)
# Out:
#           날짜  평균기온  최저기온  최고기온
# 0 2022-06-01  22.1  16.2  28.6
# 1 2022-06-02  21.5  17.1  26.9
# 2 2022-06-03  24.5  18.7  32.6
# 3 2022-06-04  25.6  20.3  29.7
# 4 2022-06-05  22.7  20.2  27.0
# 5 2022-06-06  19.7  16.7  24.5
# 6 2022-06-07  20.6  15.1  25.1
# 7 2022-06-08  21.2  16.2  25.8

# %%
#연습4 -6 df2의 요약 통계량 확인
df2.describe()
# Out:
#             평균기온       최저기온       최고기온
# count  30.000000  30.000000  30.000000
# mean   23.303333  19.846667  27.470000
# std     2.399926   3.088883   2.932828
# min    17.500000  14.900000  20.100000
# 25%    21.500000  17.300000  25.100000
# 50%    23.350000  19.900000  27.050000
# 75%    25.175000  21.975000  29.150000
# max    26.900000  25.700000  32.700000

# %%
#연습4 -7 데이터 (행, 열) 크기 확인
df2.shape
# Out:
# (30, 4)

# %%
#연습4 -8 데이터 인덱스/칼럼 명 확인
df2.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
#연습4 -9 데이터 인덱스/칼럼 명 확인
df2.columns
# Out:
# Index(['날짜', '평균기온', '최저기온', '최고기온'], dtype='object')

# %%
#연습4 -10 데이터 타입 출력
df2.dtypes
# Out:
# 날짜      datetime64[ns]
# 평균기온           float64
# 최저기온           float64
# 최고기온           float64
# dtype: object

# %%
#연습4 -11 데이터 정렬, 평균기온의 크기에 따라 오름차순 정렬
#상위 5행만 출력
df2.sort_values('평균기온').head()
# Out:
#            날짜  평균기온  최저기온  최고기온
# 14 2022-06-15  17.5  14.9  20.1
# 5  2022-06-06  19.7  16.7  24.5
# 15 2022-06-16  20.3  17.6  24.8
# 6  2022-06-07  20.6  15.1  25.1
# 9  2022-06-10  20.9  17.2  26.6

# %%
#연습4 -12 데이터 정렬, 평균기온의 크기에 따라 내림차순 정렬
#상위 5행만 출력
df2.sort_values('평균기온', ascending=False).head()
# Out:
#            날짜  평균기온  최저기온  최고기온
# 27 2022-06-28  26.9  25.7  27.9
# 26 2022-06-27  26.8  25.4  28.1
# 20 2022-06-21  26.5  21.2  32.6
# 25 2022-06-26  26.5  24.8  28.1
# 24 2022-06-25  26.0  21.5  30.5
